# %% [markdown]
# <a href="https://colab.research.google.com/github/EliasNoorzad/XAI_Autonomous-Driving/blob/main/evaluation/01_baseline_det_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install ultralytics==8.4.6
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.6 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/XAI_Project/BDD100K_640.zip /content/

# %%
# !unzip -q /content/BDD100K_640.zip -d /content/BDD100K_640

# %%
yaml = """\
path: /content/BDD100K_640/yolo_640
train: train/images
val: val/images
test: test/images

nc: 5
names: [car, truck, bus, person, bike]
"""

with open("/content/BDD100K_640/yolo_640/dataset_640.yaml", "w") as f:
    f.write(yaml)

# %%
from ultralytics import YOLO

m = YOLO("/content/drive/MyDrive/XAI_Project/experiments/det_baseline/weights/best.pt")
m.model.names = {0:"car", 1:"truck", 2:"bus", 3:"person", 4:"bike"}
m.save("/content/drive/MyDrive/XAI_Project/experiments/det_baseline/weights/best_fixednames.pt")

# %%
# !yolo detect val \
  model=/content/drive/MyDrive/XAI_Project/experiments/det_baseline/weights/best_fixednames.pt \
  data=/content/BDD100K_640/yolo_640/dataset_640.yaml \
  project=/content/drive/MyDrive/XAI_Project/experiments/det_baseline/runs \
  split=test \
  imgsz=640 \
  device=0
# Out:
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 73 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1812.1±500.9 MB/s, size: 77.8 KB)
# val: Scanning /content/BDD100K_640/yolo_640/test/labels.cache... 20000 images, 143 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 20000/20000 2.5Git/s 0.0s
# val: /content/BDD100K_640/yolo_640/test/images/e6f10c58-c46de527.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1250/1250 5.6it/s 3:44
#                    all      20000     243649      0.646      0.478      0.531      0.328
#                    car      19776     205093      0.747      0.687      0.744      0.458
#                  truck       5500       8701      0.657       0.49      0.561      0.403
#                    bus       2459       3217      0.624      0.446      0.506      0.385
# ...
